# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Gowthami.K\Downloads\iplauction2023.csv')

# %%
data
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
data.groupby('franchise')['name'].count().sort_values(ascending= True).head(1)
# Out:
# franchise
# KKR    19
# Name: name, dtype: int64

# %%
df1 = data[data['status']== 'RETAINED']

# %%
df1
# Out:
#                     name player style   nationality  base price (in lacs)  \
# 0           Harshit Rana       Bowler         India                   NaN
# 152        Rajat Patidar       Batter         India                   NaN
# 153  Matheesha Pathirana       Bowler     Sri Lanka                   NaN
# 154       Tristan Stubbs    WK-Batter  South Africa                   NaN
# 155         Ravi Bishnoi       Bowler         India                   NaN
# ..                   ...          ...           ...                   ...
# 304             MS Dhoni    WK-Batter         India                   NaN
# 305            Moeen Ali   Allrounder       England                   NaN
# 306      Ruturaj Gaikwad       Batter         India                   NaN
# 307         Rishabh Pant    WK-Batter         India                   NaN
# 308           Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# ...

# %%
data.groupby('franchise')['status'].count()
# Out:
# franchise
# CSK     25
# DC      24
# GT      25
# KKR     19
# LSG     25
# MI      23
# PBKS    22
# RCB     25
# RR      25
# SRH     25
# Name: status, dtype: int64

# %%
df1
# Out:
#                     name player style   nationality  base price (in lacs)  \
# 0           Harshit Rana       Bowler         India                   NaN
# 152        Rajat Patidar       Batter         India                   NaN
# 153  Matheesha Pathirana       Bowler     Sri Lanka                   NaN
# 154       Tristan Stubbs    WK-Batter  South Africa                   NaN
# 155         Ravi Bishnoi       Bowler         India                   NaN
# ..                   ...          ...           ...                   ...
# 304             MS Dhoni    WK-Batter         India                   NaN
# 305            Moeen Ali   Allrounder       England                   NaN
# 306      Ruturaj Gaikwad       Batter         India                   NaN
# 307         Rishabh Pant    WK-Batter         India                   NaN
# 308           Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# ...

# %%
data.groupby('franchise')['status'].count().sort_values(ascending=False).head()
# Out:
# franchise
# CSK    25
# GT     25
# LSG    25
# RCB    25
# RR     25
# Name: status, dtype: int64

# %%
data.groupby(['franchise', 'player style']).count()
# Out:
#                         name  nationality  base price (in lacs)  \
# franchise player style
# CSK       Allrounder      10           10                     5
#           Batter           5            5                     2
#           Bowler           8            8                     0
#           WK-Batter        2            2                     0
# DC        Allrounder       5            5                     0
#           Batter           8            8                     3
#           Bowler          10           10                     2
#           WK-Batter        1            1                     0
# GT        Allrounder       5            5                     1
#           Batter           5            5                     1
#           Bowler          11           11                     3
#           WK-Batter        4            4                     2
# KKR       Allrounder       8            8                     3
# ...

# %%
dd = pd.read_excel(r'C:\Users\Gowthami.K\Downloads\L2G8810_Lidar_KPI_Test_Report_OD_HIL_I480_V3_ER_GER_KAFAS_GT_Part2.xlsx', sheet_name='sheet', header=61)
# Out:
# c:\Users\Gowthami.K\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
dd
# Out:
#                                          RecordingName  \
# 0    LIDAR_LJ02774_20231125_185946_G490-PDX-007-016...
# 1    LIDAR_LJ02774_20231127_160807_G490-PDX-007-016...
# 2    LIDAR_LJ02772_20231219_110310_G490-PDX-007-016...
# 3    LIDAR_LJ02772_20231219_104302_G490-PDX-007-016...
# 4    LIDAR_LJ02772_20240103_101052_G490-PDX-007-016...
# ..                                                 ...
# 289  LIDAR_LJ02772_20231219_110310_G490-PDX-007-016...
# 290  LIDAR_LJ02772_20231121_151655_G490-PDX-007-016...
# 291  LIDAR_LJ02772_20231219_104302_G490-PDX-007-016...
# 292  LIDAR_LJ02772_20240109_063931_I470-PDX-009-047...
# 293  LIDAR_LJ02774_20231128_062210_G490-PDX-007-016...
#
#                       sequenceName  \
# 0    LIDAR_LJ02774_20231125_185946
# 1    LIDAR_LJ02774_20231127_160807
# 2    LIDAR_LJ02772_20231219_110310
# 3    LIDAR_LJ02772_20231219_104302
# 4    LIDAR_LJ02772_20240103_101052
# ..                             ...
# 289  LIDAR_LJ02772_20231219_110310
# ...

# %%
dd['DUT_Age'].mean()
# Out:
# 354.1462585034014

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Columns: 141 entries, RecordingName to Found Just In Iteration
# dtypes: bool(32), float64(60), int64(34), object(15)
# memory usage: 259.7+ KB

# %%
dd1=dd.head(10)

# %%
dd.head(10)
# Out:
#                                        RecordingName  \
# 0  LIDAR_LJ02774_20231125_185946_G490-PDX-007-016...
# 1  LIDAR_LJ02774_20231127_160807_G490-PDX-007-016...
# 2  LIDAR_LJ02772_20231219_110310_G490-PDX-007-016...
# 3  LIDAR_LJ02772_20231219_104302_G490-PDX-007-016...
# 4  LIDAR_LJ02772_20240103_101052_G490-PDX-007-016...
# 5  LIDAR_LJ02772_20240103_091334_G490-PDX-007-016...
# 6  LIDAR_LJ02774_20231128_063701_G490-PDX-007-016...
# 7  LIDAR_LJ02772_20231215_140439_G490-PDX-007-016...
# 8  LIDAR_LJ02772_20240103_091334_G490-PDX-007-016...
# 9  LIDAR_LJ02772_20231121_140503_G490-PDX-007-016...
#
#                     sequenceName  \
# 0  LIDAR_LJ02774_20231125_185946
# 1  LIDAR_LJ02774_20231127_160807
# 2  LIDAR_LJ02772_20231219_110310
# 3  LIDAR_LJ02772_20231219_104302
# 4  LIDAR_LJ02772_20240103_101052
# 5  LIDAR_LJ02772_20240103_091334
# 6  LIDAR_LJ02774_20231128_063701
# 7  LIDAR_LJ02772_20231215_140439
# 8  LIDAR_LJ02772_20240103_091334
# 9  LIDAR_LJ02772_20231121_140503
#
# ...

# %%
data.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
df1[df1['franchise']=='RCB']
# Out:
#                     name player style   nationality  base price (in lacs)  \
# 152        Rajat Patidar       Batter         India                   NaN
# 159        Shahbaz Ahmed   Allrounder         India                   NaN
# 175        Siddarth Kaul       Bowler         India                   NaN
# 182           Anuj Rawat    WK-Batter         India                   NaN
# 192  Suyash Prabhudessai       Batter         India                   NaN
# 207           Finn Allen    WK-Batter   New Zealand                   NaN
# 218       Josh Hazlewood       Bowler     Australia                   NaN
# 231       Mahipal Lomror   Allrounder         India                   NaN
# 232       Dinesh Karthik    WK-Batter         India                   NaN
# 240        Harshal Patel       Bowler         India                   NaN
# 244          Karn Sharma       Bowler         India                   NaN
# 252         David Willey   Allrounder       England                   NaN
# ...

# %%
data.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
data.tail()
# Out:
#                 name player style nationality  base price (in lacs)  \
# 304         MS Dhoni    WK-Batter       India                   NaN
# 305        Moeen Ali   Allrounder     England                   NaN
# 306  Ruturaj Gaikwad       Batter       India                   NaN
# 307     Rishabh Pant    WK-Batter       India                   NaN
# 308       Axar Patel   Allrounder       India                   NaN
#
#      final price (in lacs) franchise    status
# 304                 1200.0       CSK  RETAINED
# 305                  800.0       CSK  RETAINED
# 306                  600.0       CSK  RETAINED
# 307                 1600.0        DC  RETAINED
# 308                  900.0        DC  RETAINED

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
data.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
data['base price (in lacs)'].mean()
# Out:
# 59.205298013245034

# %%
data['final price (in lacs)'].median()
# Out:
# 150.0

# %%
data[data['name']=='MS Dhoni'].sum()
# Out:
# name                      MS Dhoni
# player style             WK-Batter
# nationality                  India
# base price (in lacs)           0.0
# final price (in lacs)       1200.0
# franchise                      CSK
# status                    RETAINED
# dtype: object

# %%
data.loc[5:10]
# Out:
#                     name player style  nationality  base price (in lacs)  \
# 5           Abdul Basith   Allrounder        India                  20.0
# 6        Prashant Chopra   Allrounder        India                  20.0
# 7           Akeal Hosein       Bowler  West Indies                 100.0
# 8           Raghav Goyal       Bowler        India                  20.0
# 9   Yudhvir Singh Charak   Allrounder        India                  20.0
# 10             Luke Wood       Bowler      England                 100.0
#
#     final price (in lacs) franchise  status
# 5                    20.0        RR    SOLD
# 6                     NaN       NaN  UNSOLD
# 7                   100.0       SRH    SOLD
# 8                    20.0        MI    SOLD
# 9                    20.0       LSG    SOLD
# 10                    NaN       NaN  UNSOLD

# %%
data
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...
